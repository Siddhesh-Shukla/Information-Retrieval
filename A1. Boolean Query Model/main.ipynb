# %%
from utils.utils import getDocs
from utils.preprocess import getCleanDocs
from lib.constants import PATH_DATASET 
from lib.zone_index import createZoneIndex

# %%
docs, doc_paths = getDocs(PATH_DATASET)
clean_docs = getCleanDocs(docs)

# %%
zone_index = createZoneIndex(clean_docs)

# %%
len(zone_index.keys())
# Out:
# 15123

# %%
from lib.wildcard_search import createPermutermDictionary, getPrefixForm, prefixMatch, getActualWords

# %%
keys = list(zone_index.keys())
query = "he*"

# %%
premutermDictionary = createPermutermDictionary(keys)
prefix = getPrefixForm(query)
prefix
# Out:
# 'he'

# %%
possible_rotated_words = prefixMatch(premutermDictionary, prefix)
possible_rotated_words
# Out:
# ['helicanu$',
#  'hermen$fis',
#  'hesu$ep',
#  'hel$brot',
#  'hear$',
#  'heir$',
#  'heaven$',
#  'her$fat',
#  'her$thit',
#  'head$',
#  'henc$t',
#  'help$',
#  'hee$t',
#  'hesperid$',
#  'heap$',
#  'heek$c',
#  'henc$w',
#  'her$mot',
#  'hearken$',
#  'hell$',
#  'her$eit',
#  'her$ot',
#  'her$smot',
#  'herwis$ot',
#  'hew$sc',
#  'herefor$t',
#  'her$arc',
#  'heart$',
#  'her$neit',
#  'heat$',
#  'herea$w',
#  'he$prit',
#  'her$hit',
#  'hed$s',
#  'her$hig',
#  'helper$',
#  'held$',
#  'held$be',
#  'hen$lengt',
#  'herward$hit',
#  'heritor$in',
#  'heard$',
#  'heavi$',
#  'helican$',
#  'hen$peris',
#  'herman$fis',
#  'her$fis',
#  'heritag$',
#  'her$furt',
#  'her$wit',
#  'herein$w',
#  'herebi$w',
#  'health$',
#  'hermor$furt',
#  'heinou$',
#  'height$',
#  'hether$w',
#  'her$whet',
#  'her$blit',
#  'head$maiden',
#  'henc$',
#  'heard$un',
#  'herein$t',
#  'herald$',
#  'helm$erw',
#  'hell$s',
#  'hest$c',
#  'hecari$pot',
#  'hereto$t',
# ...

# %%
possible_words = getActualWords(possible_rotated_words, query)
